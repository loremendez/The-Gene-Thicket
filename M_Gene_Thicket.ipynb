# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # <div class="alert-info">THE GENE THICKET</div>

# %%
import os, time
import numpy as np
import pandas as pd
import seaborn as sns
import networkx as nx
import torch
import pickle
import matplotlib.pyplot as plt

from libs.runTCDF import runTCDF
from libs.network_analysis import scores, evaluation

# %%
data_types = ['synthetic', 'curated']
results_path = './Results_gene_thicket/'

# %%
for d_type in data_types:
    
    data_path = './beeline_data/' + d_type + '/'
    
    if d_type == 'synthetic':
        names = ['dyn-BF', 'dyn-BFC', 'dyn-CY', 'dyn-LI', 'dyn-LL', 'dyn-TF']
    if d_type == 'curated':
        names = ['VSC', 'mCAD', 'HSC', 'GSD']
        
    data = {}
    refs = {}

    for name in names:
    
        base_path = data_path + name + '/'
        data = {}
        refs = {}
        links = {}
    
        for folder in os.listdir(base_path):
            temp_path = os.path.join(base_path, folder)
            if os.path.isdir(temp_path):
                gem = pd.read_csv(temp_path + '/ExpressionData.csv', index_col = 0) #read gem
                pseudotime = pd.read_csv(temp_path + '/PseudoTime.csv', index_col = 0) #is distributed in columns, we need to make it one
                pseudotime_all = pd.DataFrame({'pseudotime': pseudotime.fillna(0).sum(axis=1)}) #make one pseudotime
                gem = gem.T #transpose
                gem['pseudotime'] = pseudotime_all.values #add pseudotime to gem
            
                data[folder] = gem.sort_values(by='pseudotime').drop('pseudotime', axis=1) #sort gem according to pseudotime
                refs[folder] = pd.read_csv(temp_path + '/refNetwork.csv') #ground truth
            
        #Training the model
    
        for n_levels in np.arange(3):
            times = []
            for folder in data:
                start = time.time()
                links[folder], _, _ = runTCDF(data[folder], cuda=True, levels=n_levels)
                end = time.time()
                times.append(end-start)
                torch.cuda.empty_cache()
        
            with open(results_path + 'links/' + name + '_' + str(n_levels) + '_links.pickle', 'wb') as handle:
                pickle.dump(links, handle, protocol=pickle.HIGHEST_PROTOCOL)
            
            metrics_df = pd.DataFrame()
        
            for el in links:
                tfs = data[el].columns
                genes = tfs.copy()
                metrics_df = metrics_df.append(evaluation(links[el], refs[el], tfs, genes))
            
            metrics_df.index = links.keys()
            metrics_df["time"] = np.round(times,2)
            
            metrics_df.to_csv(results_path + name + '_' + str(n_levels) +'_levels.csv')
# Out:
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.355354
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.917342
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 2.083593
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.105387
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 1.802278
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 0.512172
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 1.572991
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.018058
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.236094
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 2.997595
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 2.438334
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 2.352376
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 2.441411
# Epoch: 500 [50%] 	Loss: 1.344541
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 2.398205
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.026140
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.027724
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 1.758706
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 3.153782
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 2.240387
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 3.263561
# Epoch: 500 [50%] 	Loss: 1.575735
# Epoch: 1000 [100%] 	Loss: 1.571773
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 2.215810
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.028405
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.179343
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 1.111556
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.261270
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 1.319580
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 1.227471
# Epoch: 500 [50%] 	Loss: 0.680581
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 1.294806
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.151574
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 1.094013
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 2.473586
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.520847
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 1.768309
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 1.239012
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 1.797300
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.023774
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.037301
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 1.606622
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 2.941499
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 2.577268
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 2.906725
# Epoch: 500 [50%] 	Loss: 1.517227
# Epoch: 1000 [100%] 	Loss: 1.506114
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 2.588037
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 1.176199
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 2.111908
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 2.792447
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.749457
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 1
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.014513
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 0.817303
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 3.785077
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 3.272684
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 3.967434
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 2.641567
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.082804
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.509520
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 1.738340
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.672448
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 1.552357
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 1.623171
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 1.495065
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.129492
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.574462
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 1.430874
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.438435
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 2.004148
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 1.404555
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 1.723475
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.080497
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.554052
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 1.592688
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.099831
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 2.086834
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 0.866551
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 2.596181
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.008490
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.010280
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 0.630069
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.815454
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 3.548100
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 2.194531
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 3.867419
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 1.111785
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 2.490326
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 3.086940
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.725083
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 1.496117
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 1.132152
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 2.557523
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.017699
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.031359
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 0.679272
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 2.841131
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 2.874910
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 2.884681
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 2.969916
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.012979
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.016020
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 1.009411
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 3.613745
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 3.671191
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 3.409108
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 3.584437
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.045758
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.145074
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 0.793204
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.947894
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 2.367470
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 1.706426
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 2.389256
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 1.356383
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 2.170429
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 2.804261
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.919915
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 2.023949
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 0.905797
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 2.725073
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.081826
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 0.494809
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 1.531837
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.596542
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 1.598914
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 1.497381
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 1.670048
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.330421
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 1.001420
# Early stopping
#
#  Analysis started for target:  g3
# Epoch:  1 [0%] 	Loss: 1.891844
# Early stopping
#
#  Analysis started for target:  g4
# Epoch:  1 [0%] 	Loss: 1.344898
# Early stopping
#
#  Analysis started for target:  g6
# Epoch:  1 [0%] 	Loss: 1.484756
# Early stopping
#
#  Analysis started for target:  g7
# Epoch:  1 [0%] 	Loss: 1.077226
# Early stopping
#
#  Analysis started for target:  g8
# Epoch:  1 [0%] 	Loss: 1.621291
# Early stopping
#
#  Analysis started for target:  g1
# Epoch:  1 [0%] 	Loss: 0.120265
# Early stopping
#
#  Analysis started for target:  g2
# Epoch:  1 [0%] 	Loss: 1.077447
# ...
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 0.718089
# Early stopping
#
#  Analysis started for target:  AMH
# Epoch:  1 [0%] 	Loss: 2.129247
# Early stopping
#
#  Analysis started for target:  CBX2
# Epoch:  1 [0%] 	Loss: 0.003343
# Early stopping
#
#  Analysis started for target:  CTNNB1
# Epoch:  1 [0%] 	Loss: 1.284629
# Early stopping
#
#  Analysis started for target:  DHH
# Epoch:  1 [0%] 	Loss: 2.086412
# Early stopping
#
#  Analysis started for target:  DKK1
# Epoch:  1 [0%] 	Loss: 1.864573
# Early stopping
#
#  Analysis started for target:  DMRT1
# Epoch:  1 [0%] 	Loss: 1.883959
# Early stopping
#
#  Analysis started for target:  FGF9
# Epoch:  1 [0%] 	Loss: 2.095114
# Early stopping
#
#  Analysis started for target:  FOXL2
# Epoch:  1 [0%] 	Loss: 1.290679
# Early stopping
#
#  Analysis started for target:  GATA4
# Epoch:  1 [0%] 	Loss: 2.209708
# Early stopping
#
#  Analysis started for target:  NR0B1
# Epoch:  1 [0%] 	Loss: 1.006946
# Early stopping
#
#  Analysis started for target:  NR5A1
# Epoch:  1 [0%] 	Loss: 1.803952
# Early stopping
#
#  Analysis started for target:  PGD2
# Epoch:  1 [0%] 	Loss: 2.105543
# Early stopping
#
#  Analysis started for target:  RSPO1
# Epoch:  1 [0%] 	Loss: 1.255962
# Early stopping
#
#  Analysis started for target:  SOX9
# Epoch:  1 [0%] 	Loss: 2.114671
# Early stopping
#
#  Analysis started for target:  SRY
# Epoch:  1 [0%] 	Loss: 1.663232
# Early stopping
#
#  Analysis started for target:  UGR
# Epoch:  1 [0%] 	Loss: 0.002880
# Early stopping
#
#  Analysis started for target:  WNT4
# Epoch:  1 [0%] 	Loss: 1.222911
# Early stopping
#
#  Analysis started for target:  WT1mKTS
# Epoch:  1 [0%] 	Loss: 1.951541
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 1.461012
# Early stopping
#
#  Analysis started for target:  AMH
# Epoch:  1 [0%] 	Loss: 0.702501
# Early stopping
#
#  Analysis started for target:  CBX2
# Epoch:  1 [0%] 	Loss: 0.001950
# Early stopping
#
#  Analysis started for target:  CTNNB1
# Epoch:  1 [0%] 	Loss: 2.718339
# Early stopping
#
#  Analysis started for target:  DHH
# Epoch:  1 [0%] 	Loss: 0.735687
# Early stopping
#
#  Analysis started for target:  DKK1
# Epoch:  1 [0%] 	Loss: 0.830263
# Early stopping
#
#  Analysis started for target:  DMRT1
# Epoch:  1 [0%] 	Loss: 0.795977
# Early stopping
#
#  Analysis started for target:  FGF9
# Epoch:  1 [0%] 	Loss: 0.757807
# Early stopping
#
#  Analysis started for target:  FOXL2
# Epoch:  1 [0%] 	Loss: 2.444110
# Early stopping
#
#  Analysis started for target:  GATA4
# Epoch:  1 [0%] 	Loss: 2.914712
# Early stopping
#
#  Analysis started for target:  NR0B1
# Epoch:  1 [0%] 	Loss: 2.500749
# Early stopping
#
#  Analysis started for target:  NR5A1
# Epoch:  1 [0%] 	Loss: 0.817537
# Early stopping
#
#  Analysis started for target:  PGD2
# Epoch:  1 [0%] 	Loss: 0.774503
# Early stopping
#
#  Analysis started for target:  RSPO1
# Epoch:  1 [0%] 	Loss: 2.733378
# Early stopping
#
#  Analysis started for target:  SOX9
# Epoch:  1 [0%] 	Loss: 0.787864
# Early stopping
#
#  Analysis started for target:  SRY
# Epoch:  1 [0%] 	Loss: 0.776903
# Early stopping
#
#  Analysis started for target:  UGR
# Epoch:  1 [0%] 	Loss: 0.001489
# Early stopping
#
#  Analysis started for target:  WNT4
# Epoch:  1 [0%] 	Loss: 2.616540
# Early stopping
#
#  Analysis started for target:  WT1mKTS
# Epoch:  1 [0%] 	Loss: 2.738180
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 0.811495
# Early stopping
#
#  Analysis started for target:  AMH
# Epoch:  1 [0%] 	Loss: 2.113929
# Early stopping
#
#  Analysis started for target:  CBX2
# Epoch:  1 [0%] 	Loss: 0.002814
# Early stopping
#
#  Analysis started for target:  CTNNB1
# Epoch:  1 [0%] 	Loss: 1.277701
# Early stopping
#
#  Analysis started for target:  DHH
# Epoch:  1 [0%] 	Loss: 2.075903
# Early stopping
#
#  Analysis started for target:  DKK1
# Epoch:  1 [0%] 	Loss: 2.157016
# Early stopping
#
#  Analysis started for target:  DMRT1
# Epoch:  1 [0%] 	Loss: 2.106338
# Early stopping
#
#  Analysis started for target:  FGF9
# Epoch:  1 [0%] 	Loss: 2.079350
# Early stopping
#
#  Analysis started for target:  FOXL2
# Epoch:  1 [0%] 	Loss: 1.284201
# Early stopping
#
#  Analysis started for target:  GATA4
# Epoch:  1 [0%] 	Loss: 2.910066
# Early stopping
#
#  Analysis started for target:  NR0B1
# Epoch:  1 [0%] 	Loss: 1.223334
# Early stopping
#
#  Analysis started for target:  NR5A1
# Epoch:  1 [0%] 	Loss: 2.129611
# Early stopping
#
#  Analysis started for target:  PGD2
# Epoch:  1 [0%] 	Loss: 2.097007
# Early stopping
#
#  Analysis started for target:  RSPO1
# Epoch:  1 [0%] 	Loss: 1.285274
# Early stopping
#
#  Analysis started for target:  SOX9
# Epoch:  1 [0%] 	Loss: 2.148464
# Early stopping
#
#  Analysis started for target:  SRY
# Epoch:  1 [0%] 	Loss: 2.037267
# Early stopping
#
#  Analysis started for target:  UGR
# Epoch:  1 [0%] 	Loss: 0.002676
# Early stopping
#
#  Analysis started for target:  WNT4
# Epoch:  1 [0%] 	Loss: 1.372306
# Early stopping
#
#  Analysis started for target:  WT1mKTS
# Epoch:  1 [0%] 	Loss: 2.841973
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 1.997554
# Early stopping
#
#  Analysis started for target:  AMH
# Epoch:  1 [0%] 	Loss: 2.011600
# Early stopping
#
#  Analysis started for target:  CBX2
# Epoch:  1 [0%] 	Loss: 0.002737
# Early stopping
#
#  Analysis started for target:  CTNNB1
# Epoch:  1 [0%] 	Loss: 1.728977
# Early stopping
#
#  Analysis started for target:  DHH
# Epoch:  1 [0%] 	Loss: 2.081746
# Early stopping
#
#  Analysis started for target:  DKK1
# Epoch:  1 [0%] 	Loss: 2.136523
# Early stopping
#
#  Analysis started for target:  DMRT1
# Epoch:  1 [0%] 	Loss: 2.087513
# Early stopping
#
#  Analysis started for target:  FGF9
# Epoch:  1 [0%] 	Loss: 2.093435
# Early stopping
#
#  Analysis started for target:  FOXL2
# Epoch:  1 [0%] 	Loss: 1.670829
# Early stopping
#
#  Analysis started for target:  GATA4
# Epoch:  1 [0%] 	Loss: 3.907880
# Early stopping
#
#  Analysis started for target:  NR0B1
# Epoch:  1 [0%] 	Loss: 1.825240
# Early stopping
#
#  Analysis started for target:  NR5A1
# Epoch:  1 [0%] 	Loss: 2.092052
# Early stopping
#
#  Analysis started for target:  PGD2
# Epoch:  1 [0%] 	Loss: 2.124984
# Early stopping
#
#  Analysis started for target:  RSPO1
# Epoch:  1 [0%] 	Loss: 1.721448
# Early stopping
#
#  Analysis started for target:  SOX9
# Epoch:  1 [0%] 	Loss: 2.072523
# Early stopping
#
#  Analysis started for target:  SRY
# Epoch:  1 [0%] 	Loss: 2.217113
# Early stopping
#
#  Analysis started for target:  UGR
# Epoch:  1 [0%] 	Loss: 0.001956
# Early stopping
#
#  Analysis started for target:  WNT4
# Epoch:  1 [0%] 	Loss: 1.810011
# Early stopping
#
#  Analysis started for target:  WT1mKTS
# Epoch:  1 [0%] 	Loss: 3.919103
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 2.109053
# Early stopping
#
#  Analysis started for target:  AMH
# Epoch:  1 [0%] 	Loss: 2.295661
# Early stopping
#
#  Analysis started for target:  CBX2
# Epoch:  1 [0%] 	Loss: 0.003740
# Early stopping
#
#  Analysis started for target:  CTNNB1
# Epoch:  1 [0%] 	Loss: 1.553954
# Early stopping
#
#  Analysis started for target:  DHH
# Epoch:  1 [0%] 	Loss: 2.324929
# Early stopping
#
#  Analysis started for target:  DKK1
# Epoch:  1 [0%] 	Loss: 2.101442
# Early stopping
#
#  Analysis started for target:  DMRT1
# Epoch:  1 [0%] 	Loss: 2.094111
# Early stopping
#
#  Analysis started for target:  FGF9
# Epoch:  1 [0%] 	Loss: 2.417472
# Early stopping
#
#  Analysis started for target:  FOXL2
# Epoch:  1 [0%] 	Loss: 1.461451
# Early stopping
#
#  Analysis started for target:  GATA4
# Epoch:  1 [0%] 	Loss: 2.253056
# Early stopping
#
#  Analysis started for target:  NR0B1
# Epoch:  1 [0%] 	Loss: 1.243789
# Early stopping
#
#  Analysis started for target:  NR5A1
# Epoch:  1 [0%] 	Loss: 2.000114
# Early stopping
#
#  Analysis started for target:  PGD2
# Epoch:  1 [0%] 	Loss: 2.350613
# Early stopping
#
#  Analysis started for target:  RSPO1
# Epoch:  1 [0%] 	Loss: 1.521288
# Early stopping
#
#  Analysis started for target:  SOX9
# Epoch:  1 [0%] 	Loss: 2.273952
# Early stopping
#
#  Analysis started for target:  SRY
# Epoch:  1 [0%] 	Loss: 1.897600
# Early stopping
#
#  Analysis started for target:  UGR
# Epoch:  1 [0%] 	Loss: 0.003172
# Early stopping
#
#  Analysis started for target:  WNT4
# Epoch:  1 [0%] 	Loss: 1.262661
# Early stopping
#
#  Analysis started for target:  WT1mKTS
# Epoch:  1 [0%] 	Loss: 2.344621
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 1.701537
# Early stopping
#
#  Analysis started for target:  AMH
# Epoch:  1 [0%] 	Loss: 2.198212
# Early stopping
#
#  Analysis started for target:  CBX2
# Epoch:  1 [0%] 	Loss: 0.003301
# Early stopping
#
#  Analysis started for target:  CTNNB1
# Epoch:  1 [0%] 	Loss: 1.040679
# Early stopping
#
#  Analysis started for target:  DHH
# Epoch:  1 [0%] 	Loss: 2.265743
# Early stopping
#
#  Analysis started for target:  DKK1
# Epoch:  1 [0%] 	Loss: 2.301087
# Early stopping
#
#  Analysis started for target:  DMRT1
# Epoch:  1 [0%] 	Loss: 2.333786
# Early stopping
#
#  Analysis started for target:  FGF9
# Epoch:  1 [0%] 	Loss: 2.310793
# Early stopping
#
#  Analysis started for target:  FOXL2
# Epoch:  1 [0%] 	Loss: 0.958971
# Early stopping
#
#  Analysis started for target:  GATA4
# Epoch:  1 [0%] 	Loss: 2.863841
# Early stopping
#
#  Analysis started for target:  NR0B1
# Epoch:  1 [0%] 	Loss: 1.082661
# Early stopping
#
#  Analysis started for target:  NR5A1
# Epoch:  1 [0%] 	Loss: 2.238402
# Early stopping
#
#  Analysis started for target:  PGD2
# Epoch:  1 [0%] 	Loss: 2.342743
# Early stopping
#
#  Analysis started for target:  RSPO1
# Epoch:  1 [0%] 	Loss: 1.010666
# Early stopping
#
#  Analysis started for target:  SOX9
# Epoch:  1 [0%] 	Loss: 2.352874
# Early stopping
#
#  Analysis started for target:  SRY
# Epoch:  1 [0%] 	Loss: 2.280635
# Early stopping
#
#  Analysis started for target:  UGR
# Epoch:  1 [0%] 	Loss: 0.002587
# Early stopping
#
#  Analysis started for target:  WNT4
# Epoch:  1 [0%] 	Loss: 1.081823
# Early stopping
#
#  Analysis started for target:  WT1mKTS
# Epoch:  1 [0%] 	Loss: 2.640371
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 2.012877
# Early stopping
#
#  Analysis started for target:  AMH
# Epoch:  1 [0%] 	Loss: 3.203484
# Early stopping
#
#  Analysis started for target:  CBX2
# Epoch:  1 [0%] 	Loss: 0.003902
# Early stopping
#
#  Analysis started for target:  CTNNB1
# Epoch:  1 [0%] 	Loss: 0.901371
# Early stopping
#
#  Analysis started for target:  DHH
# Epoch:  1 [0%] 	Loss: 3.014299
# Early stopping
#
#  Analysis started for target:  DKK1
# Epoch:  1 [0%] 	Loss: 2.931797
# Early stopping
#
#  Analysis started for target:  DMRT1
# Epoch:  1 [0%] 	Loss: 3.120934
# Early stopping
#
#  Analysis started for target:  FGF9
# Epoch:  1 [0%] 	Loss: 3.111430
# Early stopping
#
#  Analysis started for target:  FOXL2
# Epoch:  1 [0%] 	Loss: 0.843462
# Early stopping
#
#  Analysis started for target:  GATA4
# Epoch:  1 [0%] 	Loss: 4.158159
# Early stopping
#
#  Analysis started for target:  NR0B1
# Epoch:  1 [0%] 	Loss: 0.865037
# Early stopping
#
#  Analysis started for target:  NR5A1
# Epoch:  1 [0%] 	Loss: 3.014738
# Early stopping
#
#  Analysis started for target:  PGD2
# Epoch:  1 [0%] 	Loss: 3.063924
# Early stopping
#
#  Analysis started for target:  RSPO1
# Epoch:  1 [0%] 	Loss: 0.917338
# Early stopping
#
#  Analysis started for target:  SOX9
# Epoch:  1 [0%] 	Loss: 3.247855
# Early stopping
#
#  Analysis started for target:  SRY
# Epoch:  1 [0%] 	Loss: 3.054343
# Early stopping
#
#  Analysis started for target:  UGR
# Epoch:  1 [0%] 	Loss: 0.003127
# Early stopping
#
#  Analysis started for target:  WNT4
# Epoch:  1 [0%] 	Loss: 0.939616
# Early stopping
#
#  Analysis started for target:  WT1mKTS
# Epoch:  1 [0%] 	Loss: 3.878759
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 3.028680
# Early stopping
#
#  Analysis started for target:  AMH
# Epoch:  1 [0%] 	Loss: 0.697856
# Early stopping
#
#  Analysis started for target:  CBX2
# Epoch:  1 [0%] 	Loss: 0.001610
# Early stopping
#
#  Analysis started for target:  CTNNB1
# Epoch:  1 [0%] 	Loss: 2.724918
# Early stopping
#
#  Analysis started for target:  DHH
# Epoch:  1 [0%] 	Loss: 0.730511
# Early stopping
#
#  Analysis started for target:  DKK1
# Epoch:  1 [0%] 	Loss: 0.825211
# Early stopping
#
#  Analysis started for target:  DMRT1
# Epoch:  1 [0%] 	Loss: 0.791230
# Early stopping
#
#  Analysis started for target:  FGF9
# Epoch:  1 [0%] 	Loss: 0.752975
# Early stopping
#
#  Analysis started for target:  FOXL2
# Epoch:  1 [0%] 	Loss: 2.432158
# Early stopping
#
#  Analysis started for target:  GATA4
# Epoch:  1 [0%] 	Loss: 3.512568
# Early stopping
#
#  Analysis started for target:  NR0B1
# Epoch:  1 [0%] 	Loss: 2.746991
# Early stopping
#
#  Analysis started for target:  NR5A1
# Epoch:  1 [0%] 	Loss: 0.821205
# Early stopping
#
#  Analysis started for target:  PGD2
# Epoch:  1 [0%] 	Loss: 0.775683
# Early stopping
#
#  Analysis started for target:  RSPO1
# Epoch:  1 [0%] 	Loss: 2.775888
# Early stopping
#
#  Analysis started for target:  SOX9
# Epoch:  1 [0%] 	Loss: 0.789199
# Early stopping
#
#  Analysis started for target:  SRY
# Epoch:  1 [0%] 	Loss: 0.778200
# Early stopping
#
#  Analysis started for target:  UGR
# Epoch:  1 [0%] 	Loss: 0.001165
# Early stopping
#
#  Analysis started for target:  WNT4
# Epoch:  1 [0%] 	Loss: 2.828101
# Early stopping
#
#  Analysis started for target:  WT1mKTS
# Epoch:  1 [0%] 	Loss: 3.344380
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 0.830181
# Early stopping
#
#  Analysis started for target:  AMH
# Epoch:  1 [0%] 	Loss: 2.471395
# Early stopping
#
#  Analysis started for target:  CBX2
# Epoch:  1 [0%] 	Loss: 0.002856
# Early stopping
#
#  Analysis started for target:  CTNNB1
# Epoch:  1 [0%] 	Loss: 1.550086
# Early stopping
#
#  Analysis started for target:  DHH
# Epoch:  1 [0%] 	Loss: 2.446740
# Early stopping
#
#  Analysis started for target:  DKK1
# Epoch:  1 [0%] 	Loss: 2.463755
# Early stopping
#
#  Analysis started for target:  DMRT1
# Epoch:  1 [0%] 	Loss: 2.465043
# Early stopping
#
#  Analysis started for target:  FGF9
# Epoch:  1 [0%] 	Loss: 2.460568
# Early stopping
#
#  Analysis started for target:  FOXL2
# Epoch:  1 [0%] 	Loss: 1.565877
# Early stopping
#
#  Analysis started for target:  GATA4
# Epoch:  1 [0%] 	Loss: 4.095159
# Early stopping
#
#  Analysis started for target:  NR0B1
# Epoch:  1 [0%] 	Loss: 1.558102
# Early stopping
#
#  Analysis started for target:  NR5A1
# Epoch:  1 [0%] 	Loss: 2.553328
# Early stopping
#
#  Analysis started for target:  PGD2
# Epoch:  1 [0%] 	Loss: 2.382996
# Early stopping
#
#  Analysis started for target:  RSPO1
# Epoch:  1 [0%] 	Loss: 1.619461
# Early stopping
#
#  Analysis started for target:  SOX9
# Epoch:  1 [0%] 	Loss: 2.534471
# Early stopping
#
#  Analysis started for target:  SRY
# Epoch:  1 [0%] 	Loss: 2.540009
# Early stopping
#
#  Analysis started for target:  UGR
# Epoch:  1 [0%] 	Loss: 0.002462
# Early stopping
#
#  Analysis started for target:  WNT4
# Epoch:  1 [0%] 	Loss: 1.669424
# Early stopping
#
#  Analysis started for target:  WT1mKTS
# Epoch:  1 [0%] 	Loss: 4.077900
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 2.503824
# Early stopping
#
#  Analysis started for target:  AMH
# Epoch:  1 [0%] 	Loss: 2.268930
# Early stopping
#
#  Analysis started for target:  CBX2
# Epoch:  1 [0%] 	Loss: 0.003542
# Early stopping
#
#  Analysis started for target:  CTNNB1
# Epoch:  1 [0%] 	Loss: 1.535913
# Early stopping
#
#  Analysis started for target:  DHH
# Epoch:  1 [0%] 	Loss: 2.302999
# Early stopping
#
#  Analysis started for target:  DKK1
# Epoch:  1 [0%] 	Loss: 2.407478
# Early stopping
#
#  Analysis started for target:  DMRT1
# Epoch:  1 [0%] 	Loss: 2.369529
# Early stopping
#
#  Analysis started for target:  FGF9
# Epoch:  1 [0%] 	Loss: 2.385369
# Early stopping
#
#  Analysis started for target:  FOXL2
# Epoch:  1 [0%] 	Loss: 1.442804
# Early stopping
#
#  Analysis started for target:  GATA4
# Epoch:  1 [0%] 	Loss: 3.185268
# Early stopping
#
#  Analysis started for target:  NR0B1
# Epoch:  1 [0%] 	Loss: 1.563127
# Early stopping
#
#  Analysis started for target:  NR5A1
# Epoch:  1 [0%] 	Loss: 2.373483
# Early stopping
#
#  Analysis started for target:  PGD2
# Epoch:  1 [0%] 	Loss: 2.334388
# Early stopping
#
#  Analysis started for target:  RSPO1
# Epoch:  1 [0%] 	Loss: 1.554970
# Early stopping
#
#  Analysis started for target:  SOX9
# Epoch:  1 [0%] 	Loss: 2.345813
# Early stopping
#
#  Analysis started for target:  SRY
# Epoch:  1 [0%] 	Loss: 2.341957
# Early stopping
#
#  Analysis started for target:  UGR
# Epoch:  1 [0%] 	Loss: 0.002945
# Early stopping
#
#  Analysis started for target:  WNT4
# Epoch:  1 [0%] 	Loss: 1.519948
# Early stopping
#
#  Analysis started for target:  WT1mKTS
# Epoch:  1 [0%] 	Loss: 3.123490
# Early stopping
#
#  Analysis started for target:  WT1pKTS
# Epoch:  1 [0%] 	Loss: 2.111374
# Early stopping
